# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
df = pd.read_csv('Churn_Modelling.csv')

y = df['Exited'].values
df = df.drop('Exited', axis=1)

# Perform one-hot encoding on the "Geography" and "Gender" column
df = pd.get_dummies(df, columns=['Geography', 'Gender'])

# Disregarding "Row Number", "Surname", and "Customer ID" columns
df = df.iloc[:, 3:]

x = df.iloc[:,:]
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

df.head()
# Out:
#    CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0          619   42       2       0.00              1          1
# 1          608   41       1   83807.86              1          0
# 2          502   42       8  159660.80              3          1
# 3          699   39       1       0.00              2          0
# 4          850   43       2  125510.82              1          1
#
#    IsActiveMember  EstimatedSalary  Geography_France  Geography_Germany  \
# 0               1        101348.88              True              False
# 1               1        112542.58             False              False
# 2               0        113931.57              True              False
# 3               0         93826.63              True              False
# 4               1         79084.10             False              False
#
#    Geography_Spain  Gender_Female  Gender_Male
# 0            False           True        False
# 1             True           True        False
# 2            False           True        False
# 3            False           True        False
# 4             True           True        False

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# Normalize the features using StandardScaler
scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

tracker = {}
accuracies = []

for i in range(1, 30):
    # Create a KNN classifier
    knn_classifier = KNeighborsClassifier(n_neighbors=i)  # You can adjust the number of neighbors (k) as needed

    # Train the classifier
    knn_classifier.fit(x_train_scaled, y_train)

    # Make predictions on the test set
    y_pred = knn_classifier.predict(x_test_scaled)

    # Evaluate the performance
    neighbors = i
    accuracy = accuracy_score(y_test, y_pred)
    conf_matrix = confusion_matrix(y_test, y_pred)
    classification_rep = classification_report(y_test, y_pred)
    accuracies.append(accuracy)
    tracker[accuracy] = i

    print(f'Neighbors: {neighbors}')
    print(f'Accuracy: {accuracy}')
    print(f'Confusion Matrix:\n{conf_matrix}')
    print(f'Classification Report:\n{classification_rep}')

print('\nMAXIMUM ACCURACY:')
print('Neighbors: ' + str(tracker[max(accuracies)]))
print('Accuracy: ' + str(max(accuracies)))
# Out:
# Neighbors: 1
# Accuracy: 0.802
# Confusion Matrix:
# [[1422  185]
#  [ 211  182]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.87      0.88      0.88      1607
#            1       0.50      0.46      0.48       393
#
#     accuracy                           0.80      2000
#    macro avg       0.68      0.67      0.68      2000
# weighted avg       0.80      0.80      0.80      2000
#
# Neighbors: 2
# Accuracy: 0.8375
# Confusion Matrix:
# [[1560   47]
#  [ 278  115]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.85      0.97      0.91      1607
#            1       0.71      0.29      0.41       393
#
#     accuracy                           0.84      2000
#    macro avg       0.78      0.63      0.66      2000
# weighted avg       0.82      0.84      0.81      2000
#
# Neighbors: 3
# Accuracy: 0.832
# Confusion Matrix:
# [[1496  111]
#  [ 225  168]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.87      0.93      0.90      1607
#            1       0.60      0.43      0.50       393
#
#     accuracy                           0.83      2000
#    macro avg       0.74      0.68      0.70      2000
# weighted avg       0.82      0.83      0.82      2000
#
# Neighbors: 4
# Accuracy: 0.829
# Confusion Matrix:
# [[1552   55]
#  [ 287  106]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.84      0.97      0.90      1607
#            1       0.66      0.27      0.38       393
#
#     accuracy                           0.83      2000
#    macro avg       0.75      0.62      0.64      2000
# weighted avg       0.81      0.83      0.80      2000
#
# Neighbors: 5
# Accuracy: 0.829
# Confusion Matrix:
# [[1514   93]
#  [ 249  144]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.86      0.94      0.90      1607
#            1       0.61      0.37      0.46       393
#
#     accuracy                           0.83      2000
#    macro avg       0.73      0.65      0.68      2000
# weighted avg       0.81      0.83      0.81      2000
#
# Neighbors: 6
# Accuracy: 0.8325
# Confusion Matrix:
# [[1552   55]
#  [ 280  113]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.85      0.97      0.90      1607
#            1       0.67      0.29      0.40       393
#
#     accuracy                           0.83      2000
#    macro avg       0.76      0.63      0.65      2000
# weighted avg       0.81      0.83      0.80      2000
#
# Neighbors: 7
# Accuracy: 0.8325
# Confusion Matrix:
# [[1523   84]
#  [ 251  142]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.86      0.95      0.90      1607
#            1       0.63      0.36      0.46       393
#
#     accuracy                           0.83      2000
#    macro avg       0.74      0.65      0.68      2000
# weighted avg       0.81      0.83      0.81      2000
#
# Neighbors: 8
# Accuracy: 0.83
# Confusion Matrix:
# [[1552   55]
#  [ 285  108]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.84      0.97      0.90      1607
#            1       0.66      0.27      0.39       393
#
#     accuracy                           0.83      2000
#    macro avg       0.75      0.62      0.64      2000
# weighted avg       0.81      0.83      0.80      2000
#
# Neighbors: 9
# Accuracy: 0.8345
# Confusion Matrix:
# [[1540   67]
#  [ 264  129]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.85      0.96      0.90      1607
#            1       0.66      0.33      0.44       393
#
#     accuracy                           0.83      2000
#    macro avg       0.76      0.64      0.67      2000
# weighted avg       0.82      0.83      0.81      2000
#
# Neighbors: 10
# Accuracy: 0.835
# Confusion Matrix:
# [[1561   46]
#  [ 284  109]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.85      0.97      0.90      1607
#            1       0.70      0.28      0.40       393
#
#     accuracy                           0.83      2000
#    macro avg       0.77      0.62      0.65      2000
# weighted avg       0.82      0.83      0.80      2000
#
# Neighbors: 11
# Accuracy: 0.8335
# Confusion Matrix:
# [[1544   63]
#  [ 270  123]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.85      0.96      0.90      1607
#            1       0.66      0.31      0.42       393
#
#     accuracy                           0.83      2000
#    macro avg       0.76      0.64      0.66      2000
# weighted avg       0.81      0.83      0.81      2000
#
# Neighbors: 12
# Accuracy: 0.835
# Confusion Matrix:
# [[1562   45]
#  [ 285  108]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.85      0.97      0.90      1607
#            1       0.71      0.27      0.40       393
#
#     accuracy                           0.83      2000
#    macro avg       0.78      0.62      0.65      2000
# weighted avg       0.82      0.83      0.80      2000
#
# Neighbors: 13
# Accuracy: 0.8355
# Confusion Matrix:
# [[1548   59]
#  [ 270  123]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.85      0.96      0.90      1607
#            1       0.68      0.31      0.43       393
#
#     accuracy                           0.84      2000
#    macro avg       0.76      0.64      0.67      2000
# weighted avg       0.82      0.84      0.81      2000
#
# Neighbors: 14
# Accuracy: 0.8395
# Confusion Matrix:
# [[1570   37]
#  [ 284  109]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.85      0.98      0.91      1607
#            1       0.75      0.28      0.40       393
#
#     accuracy                           0.84      2000
#    macro avg       0.80      0.63      0.66      2000
# weighted avg       0.83      0.84      0.81      2000
#
# Neighbors: 15
# Accuracy: 0.8385
# Confusion Matrix:
# [[1554   53]
#  [ 270  123]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.85      0.97      0.91      1607
#            1       0.70      0.31      0.43       393
#
#     accuracy                           0.84      2000
#    macro avg       0.78      0.64      0.67      2000
# weighted avg       0.82      0.84      0.81      2000
#
# Neighbors: 16
# Accuracy: 0.8375
# Confusion Matrix:
# [[1566   41]
#  [ 284  109]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.85      0.97      0.91      1607
#            1       0.73      0.28      0.40       393
#
#     accuracy                           0.84      2000
#    macro avg       0.79      0.63      0.65      2000
# weighted avg       0.82      0.84      0.81      2000
#
# Neighbors: 17
# Accuracy: 0.8395
# Confusion Matrix:
# [[1557   50]
#  [ 271  122]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.85      0.97      0.91      1607
#            1       0.71      0.31      0.43       393
#
#     accuracy                           0.84      2000
#    macro avg       0.78      0.64      0.67      2000
# weighted avg       0.82      0.84      0.81      2000
#
# Neighbors: 18
# Accuracy: 0.8355
# Confusion Matrix:
# [[1566   41]
#  [ 288  105]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.84      0.97      0.90      1607
#            1       0.72      0.27      0.39       393
#
#     accuracy                           0.84      2000
#    macro avg       0.78      0.62      0.65      2000
# weighted avg       0.82      0.84      0.80      2000
#
# Neighbors: 19
# Accuracy: 0.8395
# Confusion Matrix:
# [[1559   48]
#  [ 273  120]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.85      0.97      0.91      1607
#            1       0.71      0.31      0.43       393
#
#     accuracy                           0.84      2000
#    macro avg       0.78      0.64      0.67      2000
# weighted avg       0.82      0.84      0.81      2000
#
# Neighbors: 20
# Accuracy: 0.833
# Confusion Matrix:
# [[1567   40]
#  [ 294   99]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.84      0.98      0.90      1607
#            1       0.71      0.25      0.37       393
#
#     accuracy                           0.83      2000
#    macro avg       0.78      0.61      0.64      2000
# weighted avg       0.82      0.83      0.80      2000
# Neighbors: 21
# Accuracy: 0.834
# Confusion Matrix:
# [[1558   49]
#  [ 283  110]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.85      0.97      0.90      1607
#            1       0.69      0.28      0.40       393
#
#     accuracy                           0.83      2000
#    macro avg       0.77      0.62      0.65      2000
# weighted avg       0.82      0.83      0.80      2000
#
# Neighbors: 22
# Accuracy: 0.8335
# Confusion Matrix:
# [[1569   38]
#  [ 295   98]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.84      0.98      0.90      1607
#            1       0.72      0.25      0.37       393
#
#     accuracy                           0.83      2000
#    macro avg       0.78      0.61      0.64      2000
# weighted avg       0.82      0.83      0.80      2000
#
# Neighbors: 23
# Accuracy: 0.836
# Confusion Matrix:
# [[1562   45]
#  [ 283  110]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.85      0.97      0.90      1607
#            1       0.71      0.28      0.40       393
#
#     accuracy                           0.84      2000
#    macro avg       0.78      0.63      0.65      2000
# weighted avg       0.82      0.84      0.81      2000
#
# Neighbors: 24
# Accuracy: 0.835
# Confusion Matrix:
# [[1574   33]
#  [ 297   96]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.84      0.98      0.91      1607
#            1       0.74      0.24      0.37       393
#
#     accuracy                           0.83      2000
#    macro avg       0.79      0.61      0.64      2000
# weighted avg       0.82      0.83      0.80      2000
#
# Neighbors: 25
# Accuracy: 0.8365
# Confusion Matrix:
# [[1569   38]
#  [ 289  104]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.84      0.98      0.91      1607
#            1       0.73      0.26      0.39       393
#
#     accuracy                           0.84      2000
#    macro avg       0.79      0.62      0.65      2000
# weighted avg       0.82      0.84      0.80      2000
#
# Neighbors: 26
# Accuracy: 0.834
# Confusion Matrix:
# [[1578   29]
#  [ 303   90]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.84      0.98      0.90      1607
#            1       0.76      0.23      0.35       393
#
#     accuracy                           0.83      2000
#    macro avg       0.80      0.61      0.63      2000
# weighted avg       0.82      0.83      0.80      2000
#
# Neighbors: 27
# Accuracy: 0.834
# Confusion Matrix:
# [[1572   35]
#  [ 297   96]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.84      0.98      0.90      1607
#            1       0.73      0.24      0.37       393
#
#     accuracy                           0.83      2000
#    macro avg       0.79      0.61      0.64      2000
# weighted avg       0.82      0.83      0.80      2000
#
# Neighbors: 28
# Accuracy: 0.834
# Confusion Matrix:
# [[1579   28]
#  [ 304   89]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.84      0.98      0.90      1607
#            1       0.76      0.23      0.35       393
#
#     accuracy                           0.83      2000
#    macro avg       0.80      0.60      0.63      2000
# weighted avg       0.82      0.83      0.80      2000
#
# Neighbors: 29
# Accuracy: 0.833
# Confusion Matrix:
# [[1573   34]
#  [ 300   93]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.84      0.98      0.90      1607
#            1       0.73      0.24      0.36       393
#
#     accuracy                           0.83      2000
#    macro avg       0.79      0.61      0.63      2000
# weighted avg       0.82      0.83      0.80      2000
#
#
# MAXIMUM ACCURACY:
# Neighbors: 19
# Accuracy: 0.8395
